# %% [markdown]
# # Describing Distributions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %%
filename = 'Data/datadescription.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
vitD = df['VitD_levels']
mean_vitD = vitD.mean()
median_vitD = vitD.median()
std_vitD = vitD.std()
plus_one_std_vitD = mean_vitD + std_vitD
minus_one_std_vitD = mean_vitD - std_vitD
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(vitD, ax=ax, stat= 'probability', kde = True)
ax.axvline(mean_vitD, color = 'red', label = f'Mean = {mean_vitD:,.2f}',)
ax.axvline(median_vitD, ls='--', color = 'green', label = f'Median = {median_vitD:,.2f}')
ax.axvline(plus_one_std_vitD, color = 'black',label=f'+1 std = {plus_one_std_vitD:,.2f}')
ax.axvline(minus_one_std_vitD, color = 'black', label = f'-1 std = {minus_one_std_vitD:,.2f}')
ax.axvspan(plus_one_std_vitD, minus_one_std_vitD, color = 'yellow', zorder = 0)
ax.set_title(f'VitD_levels')
ax.legend();

# %%
from scipy import stats
kurt_vit = stats.kurtosis(df['VitD_levels'], fisher = False)
kurt_vit
# Out:
# 3.013147515833447

# %% [markdown]
# Answer the following questions:
# - Is it Discrete or Continuous?
# - Does it have a skew? If so, which direction (+/-)
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# 1. This is Continuous
# 2. Slight positive skew
# 3. This has a Mesokurtic kurtosis.

# %%
doc = df['Doc_visits']
mean_doc = doc.mean()
median_doc = doc.median()
std_doc = doc.std()
plus_one_std_doc = mean_doc + std_doc
minus_one_std_doc = mean_doc - std_doc
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(doc, ax=ax, stat= 'density', kde = True)
ax.axvline(mean_doc, color = 'red', label = f'Mean = {mean_doc:,.2f}',)
ax.axvline(median_doc, ls='--', color = 'green', label = f'Median = {median_doc:,.2f}')
ax.axvline(plus_one_std_doc, color = 'black',label=f'+1 std = {plus_one_std_doc:,.2f}')
ax.axvline(minus_one_std_doc, color = 'black', label = f'-1 std = {minus_one_std_doc:,.2f}')
ax.axvspan(plus_one_std_doc, minus_one_std_doc, color = 'yellow', zorder = 0)
ax.set_title(f'Doc Visits')
ax.legend();

# %% [markdown]
# Answer the following questions:
# - Is it Discrete or Continuous?
# - Does it have a skew? If so, which direction (+/-)
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# 1. This is a discrete
# 2. No skew
# 3. This is a Mesokurtic kurtosis.

# %%
kurt_doc = stats.kurtosis(df['Doc_visits'], fisher = False)
kurt_doc
# Out:
# 2.9919958083381206

# %%
charge = df['TotalCharge']
mean_charge = charge.mean()
median_charge = charge.median()
std_charge = charge.std()
plus_one_std_charge = mean_charge + std_charge
minus_one_std_charge = mean_charge - std_charge
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(charge, ax=ax, stat= 'probability', kde = True)
ax.axvline(mean_charge, color = 'red', label = f'Mean = {mean_charge:,.2f}',)
ax.axvline(median_charge, ls='--', color = 'green', label = f'Median = {median_charge:,.2f}')
ax.axvline(plus_one_std_charge, color = 'black',label=f'+1 std = {plus_one_std_charge:,.2f}')
ax.axvline(minus_one_std_charge, color = 'black', label = f'-1 std = {minus_one_std_charge:,.2f}')
ax.axvspan(plus_one_std_charge, minus_one_std_charge, color = 'yellow', zorder = 0)
ax.set_title(f'Total Charge')
ax.legend();

# %%
kurt_charge = stats.kurtosis(df['TotalCharge'], fisher = False)
kurt_charge
# Out:
# 3.2650077463439384

# %% [markdown]
# Answer the following questions:
# - Is it Discrete or Continuous?
# - Does it have a skew? If so, which direction (+/-)
# - What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# 1. Continuous
# 2. Positive Skew - more values are on the left
# 3. Leptokurtic
